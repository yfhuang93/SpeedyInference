# %% [markdown]
# Mount Drive

# %% [markdown]
# Following the steps to create environment.
# 1. download layer skip codebase
# 2. Copy this notebook file into layer skip code base.
# 3. run notebook in colab

# %%
from google.colab import drive

drive.mount("/content/drive")

# %% [markdown]
# environment setup

# %%
# install python 3.10 for environment
# !sudo apt-get install python3.10

# %cd '/content/drive/MyDrive/Colab_Notebooks/cs7643_deep_learning/LayerSkip/'

# install dependencies
# !pip install -r requirements.txt

# %% [markdown]
# Import python modules

# %%
import numpy as np
import torch

from huggingface_hub import notebook_login
notebook_login()

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Check devices

# %%
# Check device availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("You are using device: %s" % device)

# !cat /proc/cpuinfo | grep 'model name'

# %%
# %cd '/content/drive/MyDrive/Colab_Notebooks/cs7643_deep_learning/LayerSkip/'

# !torchrun generate.py --model facebook/layerskip-llama2-7B --generation_strategy self_speculative --exit_layer 6 --num_speculations 4
